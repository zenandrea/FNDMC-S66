# %% [markdown]
# # Analysis with python notebook of all results
#
# Steps:
#
# 1. Collect all results of the simulation on a python readable file, having done reblocking before
#
# 2. Analyze molecules, QMC versus DFT \
#     a. Analysis DMC values, timestep dependence \
#     b. Comparison with DFT and CCSD(T) (writes *results_mol_dft.pkl*, which also includes CCSD(T) results, and in *delta_mol_ref.pkl* the delta energy with respect to the refence molecule )
#
# 3. Analyze dimers binding energies \
#     a. Do extrapolations w/ w/o Jopt on molecules \
#     b. Define gold, silver, bronze schemes, and their cost
#
# 4. Compare binding energies with other references
#
# 5. Tool to predict QMC cost \
#     a. Multilinear fit of the variance \
#     b. Use of Student's t distribution to estimate cost
#
# 6. Plots for some relevant cases
#
# 7. Plots for the paper
#
# ---
#
# ## Specific tasks here:
#
# Copy data into \
#     **data[mol][method][mol_id]**, \
# where method is either the DFT functional or the DMC timestep (with err_{timestep} reporting the error).
# For DMC, consider only use **DMCdla5 Jopt**, and **mol_info[mol]['test']** is True.
# Notice that **data[mol]** can be converted in a **pd.DataFrame** with mol_id as index and method as columns.
#
# Comparison with **HF**, **DFT** (LDA, PBE, B3LYP) and **CCSD(T) cc-pV(D,T)Z** (orca)
#
# Write in a file the delta energy for each structure (mol_id) of each molecule \
#     **delta_mol_ref[mol][mol_id] = E[mol_id] - E[ref_mol_id]** \
# where E is the energy at the B3LYP level,
# such that in a molecule where only one DMC evaluation was performed, in the **ref_mol_id** structure,
# we can estimate \
#     **Edmc[mol][mol_id] ~ Edmc[mol][ref_mol_id] + delta_mol_ref[mol][mol_id]**

# %%
import os
import re
import math
import pickle 
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

from def_colors import map_DMC, dmc_color, dft_color

from define_setup import *

# Read mol_info
with open( 'mol_info.pkl', 'rb' ) as f:
    mol_info = pickle.load( f )
#mol_info

df_mol_info = pd.read_csv( 'mol_info.csv', index_col=0 )
df_mol_info

# Read results monomer
import pickle
with open( dir_analysis+'results_mol.pkl', 'rb' ) as f:
    results_mol = pickle.load( f )

# %%
# results_mol[ mol_name ][ mol_id ][ dmc_type ][ dmc_Jas ][ tau ]
# clear from fields without dmc results

list_clean = []

for mol in results_mol:
    #print(mol)
    for mol_id in results_mol[mol]:
        #print(mol_id)
        #for dmc_type in results_mol[mol][mol_id]:
            #print(dmc_type)
        if len(results_mol[mol][mol_id].keys())==0:
            print(mol,mol_id)
            list_clean.append( [mol,mol_id] )

#print(list_clean)
for l in list_clean:
    print(l)
    del results_mol[l[0]][l[1]]
# Out:
# Benzene 24_2
# Pyridine 25_2
# ['Benzene', '24_2']
# ['Pyridine', '25_2']

# %%
# read DFT results and save in
# results_mol_dft[mol][mol_id][func]
# Dropbox/WORK/2021_S66/Representative_molecules/AcNH2/ORCA_HF

import os.path as path

list_func = []
list_func.append('LDA')
list_func.append('PBE')
list_func.append('B3LYP')
list_func.append('HF')

results_mol_dft = {}
for mol in mol_names:
    results_mol_dft[mol] = {}
    moldir = f'../Representative_molecules/{mol}'
    # extract mol_id names
    l = os.listdir( moldir )
    lxyz = [ s for s in l if s.endswith('.xyz') ]
    mol_ids = [ s[:4] for s in lxyz ]
    mol_ids.sort()
    print(mol,mol_ids)

    # make results_mol_dft[mol][mol_id] dictionary
    for mol_id in mol_ids:
        results_mol_dft[mol][mol_id] = {}
    
    # read results and copy energy for each functional
    for func in list_func:
        # see if ORCA_$func_scratch exists, otherwise use ORCA_$func
        outdir = moldir + f'/ORCA_{func}'
        outdir_scra = outdir+'_scratch'
        if path.exists(outdir_scra):
            #print(f'Dir exists {outdir_scra}')
            outdir = outdir_scra
        elif path.exists(outdir):
            #print(f'Dir scratch does not exist, but {outdir} {path.exists(outdir)}')
            pass
        else:
            print(f'Directory with outputs for {mol} not found!')
        for mol_id in mol_ids:
            outfile = f'{outdir}/{mol_id}_property.txt'
            if path.exists(outfile):
                try:
                    ene = 0.
                    for line in open(outfile,'r'):
                        if re.search('SCF Energy:',line):
                            ene = float( line.split()[-1] )
                    results_mol_dft[mol][mol_id][func] = ene * conv2au['kcal/mol']
                except Exception as e:
                    print(f'Exception reading {outfile}: {e}')

# copy on file
#import pickle
#with open( dir_analysis+'results_mol_dft.pkl', 'wb' ) as f:
#    pickle.dump( results_mol, f, pickle.HIGHEST_PROTOCOL )


#results_mol_dft
# Out:
# AcNH2 ['21_1', '21_2', '23_1', '53_2', '62_2']
# AcOH ['20_1', '20_2', '22_1', '52_2', '60_2', '61_2', '63_2']
# Benzene ['24_1', '24_2', '27_1', '28_1', '30_1', '39_1', '40_1', '47_1', '47_2', '49_1', '50_1', '52_1', '53_1', '54_1', '55_1', '56_1', '57_1', '63_1']
# Cyclopentane ['37_1', '38_1', '38_2', '39_2', '42_2']
# Ethene ['30_2', '31_2', '33_2', '44_1', '64_2']
# Ethyne ['32_2', '45_1', '50_2', '51_1', '51_2', '59_1', '60_1', '65_2']
# MeNH2 ['03_2', '06_2', '09_1', '10_1', '10_2', '11_1', '12_1', '14_2', '56_2', '66_1']
# MeOH ['02_2', '05_1', '05_2', '06_1', '07_1', '08_1', '09_2', '13_2', '19_1', '55_2']
# Neopentane ['35_2', '36_1', '36_2', '37_2', '40_2', '43_2']
# Pentane ['34_1', '34_2', '35_1', '41_2', '44_2', '45_2', '46_2', '61_1', '62_1']
# Peptide ['04_2', '07_2', '11_2', '13_1', '14_1', '15_1', '15_2', '16_1', '46_1', '57_2', '64_1']
# Pyridine ['18_2', '19_2', '25_1', '25_2', '27_2', '29_1', '33_1', '48_1', '48_2', '49_2', '58_1', '58_2', '65_1', '66_2']
# Uracil ['17_1', '17_2', '22_2', '23_2', '26_1', '26_2', '28_2', '29_2', '31_1', '32_1', '41_1', '42_1', '43_1']
# Water ['01_1', '01_2', '02_1', '03_1', '04_1', '08_2', '12_2', '16_2', '18_1', '54_2', '59_2']

# %%
# read CCSD(T) results and save in
# results_mol_ccsdt[mol][mol_id][func]
# Dropbox/WORK/2021_S66/DATA_CAM/Representative_molecules_CCSDt
# From Yasmine:
# Just a note: there is Water wand Water_small. 
# The first is with CBS@aug-cc-pV[T/Q]Z and the second is with CBS@cc-pV[D/T]Z. 
# This was to compare the effect of the basis set size on the results since 
# I didn't manage to use the larger basis set for other molecules (at least not with the memory on 1 node). 
# The differences for the two sets of results are very small: 0.00-0.01 kcal/mol in the water molecules 
# so I think the CBS with the smaller basis sets is fine

list_func.append('CCSD(T)')
list_func.append('CCSD(T) small')

for mol in mol_names:
    moldir = f'../DATA_CAM/Representative_molecules_CCSDt/{mol}'
    # read results and copy energy
    for func in ['CCSD(T)','CCSD(T) small']:
        if func.endswith('small'):
            outdir = moldir + '_small'
        else:
            # see if ORCA_$func_scratch exists, otherwise use ORCA_$func
            outdir = moldir 
        for mol_id in results_mol_dft[mol].keys():
            outfile = f'{outdir}/{mol_id}_property.txt'
            if path.exists(outfile):
                try:
                    #ene = 0.
                    for line in open(outfile,'r'):
                        #print(line)
                        if re.search('CBS Total Energy',line):
                            ene = float( line.split()[-1] )
                            print( f'{mol} {mol_id} {ene} {outfile}' )
                    results_mol_dft[mol][mol_id][func] = ene * conv2au['kcal/mol']
                except Exception as e:
                    print(f'Exception reading {outfile}: {e}')

# copy on file
import pickle
with open( dir_analysis+'results_mol_dft.pkl', 'wb' ) as f:
    pickle.dump( results_mol, f, pickle.HIGHEST_PROTOCOL )


#results_mol_dft
# Out:
# AcNH2 21_1 -208.9929292839 ../DATA_CAM/Representative_molecules_CCSDt/AcNH2/21_1_property.txt
# AcNH2 21_2 -208.9929318367 ../DATA_CAM/Representative_molecules_CCSDt/AcNH2/21_2_property.txt
# AcNH2 23_1 -208.9928393305 ../DATA_CAM/Representative_molecules_CCSDt/AcNH2/23_1_property.txt
# AcNH2 53_2 -208.9939591679 ../DATA_CAM/Representative_molecules_CCSDt/AcNH2/53_2_property.txt
# AcNH2 62_2 -208.9940524393 ../DATA_CAM/Representative_molecules_CCSDt/AcNH2/62_2_property.txt
# AcNH2 21_1 -208.9984224382 ../DATA_CAM/Representative_molecules_CCSDt/AcNH2_small/21_1_property.txt
# AcNH2 21_2 -208.9984265209 ../DATA_CAM/Representative_molecules_CCSDt/AcNH2_small/21_2_property.txt
# AcNH2 23_1 -208.9983463054 ../DATA_CAM/Representative_molecules_CCSDt/AcNH2_small/23_1_property.txt
# AcNH2 53_2 -208.9995092525 ../DATA_CAM/Representative_molecules_CCSDt/AcNH2_small/53_2_property.txt
# AcNH2 62_2 -208.9995971265 ../DATA_CAM/Representative_molecules_CCSDt/AcNH2_small/62_2_property.txt
# AcOH 20_1 -228.863602626 ../DATA_CAM/Representative_molecules_CCSDt/AcOH/20_1_property.txt
# AcOH 20_2 -228.8636051432 ../DATA_CAM/Representative_molecules_CCSDt/AcOH/20_2_property.txt
# AcOH 22_1 -228.8634917267 ../DATA_CAM/Representative_molecules_CCSDt/AcOH/22_1_property.txt
# AcOH 52_2 -228.865635994 ../DATA_CAM/Representative_molecules_CCSDt/AcOH/52_2_property.txt
# AcOH 60_2 -228.8655987545 ../DATA_CAM/Representative_molecules_CCSDt/AcOH/60_2_property.txt
# AcOH 61_2 -228.8657220311 ../DATA_CAM/Representative_molecules_CCSDt/AcOH/61_2_property.txt
# Benzene 24_2 -231.9192926601 ../DATA_CAM/Representative_molecules_CCSDt/Benzene_small/24_2_property.txt
# Benzene 27_1 -231.9192719245 ../DATA_CAM/Representative_molecules_CCSDt/Benzene_small/27_1_property.txt
# Benzene 28_1 -231.919257968 ../DATA_CAM/Representative_molecules_CCSDt/Benzene_small/28_1_property.txt
# Benzene 30_1 -231.9193036058 ../DATA_CAM/Representative_molecules_CCSDt/Benzene_small/30_1_property.txt
# Benzene 39_1 -231.9192826136 ../DATA_CAM/Representative_molecules_CCSDt/Benzene_small/39_1_property.txt
# Benzene 40_1 -231.9192935426 ../DATA_CAM/Representative_molecules_CCSDt/Benzene_small/40_1_property.txt
# Benzene 47_1 -231.9192871007 ../DATA_CAM/Representative_molecules_CCSDt/Benzene_small/47_1_property.txt
# Benzene 47_2 -231.9192790048 ../DATA_CAM/Representative_molecules_CCSDt/Benzene_small/47_2_property.txt
# Benzene 49_1 -231.9192853594 ../DATA_CAM/Representative_molecules_CCSDt/Benzene_small/49_1_property.txt
# Benzene 50_1 -231.9192878399 ../DATA_CAM/Representative_molecules_CCSDt/Benzene_small/50_1_property.txt
# Benzene 52_1 -231.919255657 ../DATA_CAM/Representative_molecules_CCSDt/Benzene_small/52_1_property.txt
# Benzene 53_1 -231.9192210514 ../DATA_CAM/Representative_molecules_CCSDt/Benzene_small/53_1_property.txt
# Benzene 54_1 -231.9192812061 ../DATA_CAM/Representative_molecules_CCSDt/Benzene_small/54_1_property.txt
# Benzene 55_1 -231.9192795891 ../DATA_CAM/Representative_molecules_CCSDt/Benzene_small/55_1_property.txt
# Benzene 56_1 -231.9192906193 ../DATA_CAM/Representative_molecules_CCSDt/Benzene_small/56_1_property.txt
# Benzene 57_1 -231.9192695044 ../DATA_CAM/Representative_molecules_CCSDt/Benzene_small/57_1_property.txt
# Benzene 63_1 -231.9192795955 ../DATA_CAM/Representative_molecules_CCSDt/Benzene_small/63_1_property.txt
# Cyclopentane 37_1 -196.2777355331 ../DATA_CAM/Representative_molecules_CCSDt/Cyclopentane/37_1_property.txt
# Cyclopentane 38_1 -196.2777249218 ../DATA_CAM/Representative_molecules_CCSDt/Cyclopentane/38_1_property.txt
# Cyclopentane 38_2 -196.2777239347 ../DATA_CAM/Representative_molecules_CCSDt/Cyclopentane/38_2_property.txt
# Cyclopentane 39_2 -196.2777184699 ../DATA_CAM/Representative_molecules_CCSDt/Cyclopentane/39_2_property.txt
# Cyclopentane 42_2 -196.2776980513 ../DATA_CAM/Representative_molecules_CCSDt/Cyclopentane/42_2_property.txt
# Cyclopentane 37_1 -196.2912476103 ../DATA_CAM/Representative_molecules_CCSDt/Cyclopentane_small/37_1_property.txt
# Cyclopentane 38_1 -196.2912357245 ../DATA_CAM/Representative_molecules_CCSDt/Cyclopentane_small/38_1_property.txt
# Cyclopentane 38_2 -196.2912299241 ../DATA_CAM/Representative_molecules_CCSDt/Cyclopentane_small/38_2_property.txt
# Cyclopentane 39_2 -196.2912044438 ../DATA_CAM/Representative_molecules_CCSDt/Cyclopentane_small/39_2_property.txt
# Cyclopentane 42_2 -196.2912168755 ../DATA_CAM/Representative_molecules_CCSDt/Cyclopentane_small/42_2_property.txt
# Ethene 30_2 -78.4754683538 ../DATA_CAM/Representative_molecules_CCSDt/Ethene/30_2_property.txt
# Ethene 31_2 -78.4754686786 ../DATA_CAM/Representative_molecules_CCSDt/Ethene/31_2_property.txt
# Ethene 33_2 -78.4754685589 ../DATA_CAM/Representative_molecules_CCSDt/Ethene/33_2_property.txt
# Ethene 44_1 -78.475473493 ../DATA_CAM/Representative_molecules_CCSDt/Ethene/44_1_property.txt
# Ethene 64_2 -78.4754403748 ../DATA_CAM/Representative_molecules_CCSDt/Ethene/64_2_property.txt
# Ethene 30_2 -78.4813511348 ../DATA_CAM/Representative_molecules_CCSDt/Ethene_small/30_2_property.txt
# Ethene 31_2 -78.4813334559 ../DATA_CAM/Representative_molecules_CCSDt/Ethene_small/31_2_property.txt
# Ethene 33_2 -78.4813461518 ../DATA_CAM/Representative_molecules_CCSDt/Ethene_small/33_2_property.txt
# Ethene 44_1 -78.4813514919 ../DATA_CAM/Representative_molecules_CCSDt/Ethene_small/44_1_property.txt
# Ethene 64_2 -78.4813082033 ../DATA_CAM/Representative_molecules_CCSDt/Ethene_small/64_2_property.txt
# Ethyne 32_2 -77.2219253823 ../DATA_CAM/Representative_molecules_CCSDt/Ethyne/32_2_property.txt
# Ethyne 45_1 -77.2219678759 ../DATA_CAM/Representative_molecules_CCSDt/Ethyne/45_1_property.txt
# Ethyne 50_2 -77.2219524623 ../DATA_CAM/Representative_molecules_CCSDt/Ethyne/50_2_property.txt
# Ethyne 51_1 -77.2219735412 ../DATA_CAM/Representative_molecules_CCSDt/Ethyne/51_1_property.txt
# Ethyne 51_2 -77.2219670523 ../DATA_CAM/Representative_molecules_CCSDt/Ethyne/51_2_property.txt
# Ethyne 59_1 -77.2219415412 ../DATA_CAM/Representative_molecules_CCSDt/Ethyne/59_1_property.txt
# Ethyne 60_1 -77.2218865884 ../DATA_CAM/Representative_molecules_CCSDt/Ethyne/60_1_property.txt
# Ethyne 65_2 -77.2218797739 ../DATA_CAM/Representative_molecules_CCSDt/Ethyne/65_2_property.txt
# Ethyne 32_2 -77.2263061282 ../DATA_CAM/Representative_molecules_CCSDt/Ethyne_small/32_2_property.txt
# Ethyne 45_1 -77.2263666363 ../DATA_CAM/Representative_molecules_CCSDt/Ethyne_small/45_1_property.txt
# Ethyne 50_2 -77.2263285404 ../DATA_CAM/Representative_molecules_CCSDt/Ethyne_small/50_2_property.txt
# Ethyne 51_1 -77.2263713768 ../DATA_CAM/Representative_molecules_CCSDt/Ethyne_small/51_1_property.txt
# Ethyne 51_2 -77.2263512327 ../DATA_CAM/Representative_molecules_CCSDt/Ethyne_small/51_2_property.txt
# Ethyne 59_1 -77.226296161 ../DATA_CAM/Representative_molecules_CCSDt/Ethyne_small/59_1_property.txt
# Ethyne 60_1 -77.2262490068 ../DATA_CAM/Representative_molecules_CCSDt/Ethyne_small/60_1_property.txt
# Peptide 64_1 -248.2437076845 ../DATA_CAM/Representative_molecules_CCSDt/Peptide/64_1_property.txt
# Peptide 04_2 -248.2518757851 ../DATA_CAM/Representative_molecules_CCSDt/Peptide_small/04_2_property.txt
# Peptide 07_2 -248.251914128 ../DATA_CAM/Representative_molecules_CCSDt/Peptide_small/07_2_property.txt
# Peptide 11_2 -248.2520902001 ../DATA_CAM/Representative_molecules_CCSDt/Peptide_small/11_2_property.txt
# Peptide 13_1 -248.2518933217 ../DATA_CAM/Representative_molecules_CCSDt/Peptide_small/13_1_property.txt
# Peptide 14_1 -248.2516709523 ../DATA_CAM/Representative_molecules_CCSDt/Peptide_small/14_1_property.txt
# Peptide 15_1 -248.2517140951 ../DATA_CAM/Representative_molecules_CCSDt/Peptide_small/15_1_property.txt
# Peptide 15_2 -248.2518683556 ../DATA_CAM/Representative_molecules_CCSDt/Peptide_small/15_2_property.txt
# Peptide 16_1 -248.2519018618 ../DATA_CAM/Representative_molecules_CCSDt/Peptide_small/16_1_property.txt
# Peptide 46_1 -248.2519894911 ../DATA_CAM/Representative_molecules_CCSDt/Peptide_small/46_1_property.txt
# Peptide 57_2 -248.251975655 ../DATA_CAM/Representative_molecules_CCSDt/Peptide_small/57_2_property.txt
# Peptide 64_1 -248.2520174316 ../DATA_CAM/Representative_molecules_CCSDt/Peptide_small/64_1_property.txt
# Pyridine 18_2 -247.9434102068 ../DATA_CAM/Representative_molecules_CCSDt/Pyridine/18_2_property.txt
# Pyridine 19_2 -247.9434038577 ../DATA_CAM/Representative_molecules_CCSDt/Pyridine/19_2_property.txt
# Pyridine 25_1 -247.9434167101 ../DATA_CAM/Representative_molecules_CCSDt/Pyridine/25_1_property.txt
# Pyridine 25_2 -247.9434220586 ../DATA_CAM/Representative_molecules_CCSDt/Pyridine/25_2_property.txt
# Pyridine 27_2 -247.9434245056 ../DATA_CAM/Representative_molecules_CCSDt/Pyridine/27_2_property.txt
# Pyridine 29_1 -247.9433945414 ../DATA_CAM/Representative_molecules_CCSDt/Pyridine/29_1_property.txt
# Pyridine 33_1 -247.9434421918 ../DATA_CAM/Representative_molecules_CCSDt/Pyridine/33_1_property.txt
# Pyridine 48_1 -247.9434222688 ../DATA_CAM/Representative_molecules_CCSDt/Pyridine/48_1_property.txt
# Pyridine 48_2 -247.9434138508 ../DATA_CAM/Representative_molecules_CCSDt/Pyridine/48_2_property.txt
# Pyridine 49_2 -247.9434110852 ../DATA_CAM/Representative_molecules_CCSDt/Pyridine/49_2_property.txt
# Pyridine 58_1 -247.9433886052 ../DATA_CAM/Representative_molecules_CCSDt/Pyridine/58_1_property.txt
# Pyridine 58_2 -247.9433885935 ../DATA_CAM/Representative_molecules_CCSDt/Pyridine/58_2_property.txt
# Pyridine 65_1 -247.9434266479 ../DATA_CAM/Representative_molecules_CCSDt/Pyridine/65_1_property.txt
# Pyridine 66_2 -247.9434185663 ../DATA_CAM/Representative_molecules_CCSDt/Pyridine/66_2_property.txt
# Water 04_1 -76.3773934825 ../DATA_CAM/Representative_molecules_CCSDt/Water_small/04_1_property.txt
# Water 08_2 -76.3775405304 ../DATA_CAM/Representative_molecules_CCSDt/Water_small/08_2_property.txt
# Water 12_2 -76.3773450884 ../DATA_CAM/Representative_molecules_CCSDt/Water_small/12_2_property.txt
# Water 16_2 -76.3775423025 ../DATA_CAM/Representative_molecules_CCSDt/Water_small/16_2_property.txt
# Water 18_1 -76.3773746956 ../DATA_CAM/Representative_molecules_CCSDt/Water_small/18_1_property.txt
# Water 54_2 -76.3774866932 ../DATA_CAM/Representative_molecules_CCSDt/Water_small/54_2_property.txt
# Water 59_2 -76.37754374 ../DATA_CAM/Representative_molecules_CCSDt/Water_small/59_2_property.txt

# %%
results_mol_dft['Water']
# Out:
# {'01_1': {'LDA': -47634.938791931636,
#   'PBE': -47932.97341975782,
#   'B3LYP': -47963.613601347046,
#   'HF': -47731.86980163236,
#   'CCSD(T)': -47926.3366918831,
#   'CCSD(T) small': -47927.10630806027},
#  '01_2': {'LDA': -47634.9341715643,
#   'PBE': -47932.96956506965,
#   'B3LYP': -47963.64169942539,
#   'HF': -47731.9907393443,
#   'CCSD(T)': -47926.36766254467,
#   'CCSD(T) small': -47927.13543656128},
#  '02_1': {'LDA': -47634.95734060657,
#   'PBE': -47932.98667845697,
#   'B3LYP': -47963.61459255079,
#   'HF': -47731.831585695654,
#   'CCSD(T)': -47926.3258673936,
#   'CCSD(T) small': -47927.093482965705},
#  '03_1': {'LDA': -47634.95998251971,
#   'PBE': -47932.98022829087,
#   'B3LYP': -47963.565329800265,
#   'HF': -47731.64921255351,
#   'CCSD(T)': -47926.25891646302,
#   'CCSD(T) small': -47927.02109560013},
#  '04_1': {'LDA': -47634.969243334475,
#   'PBE': -47932.99172314184,
#   'B3LYP': -47963.58636840711,
#   'HF': -47731.7023818867,
#   'CCSD(T)': -47926.28049152217,
#   'CCSD(T) small': -47927.043542449195},
#  '08_2': {'LDA': -47634.93745572676,
#   'PBE': -47932.970920476124,
#   'B3LYP': -47963.644709118016,
#   'HF': -47731.99616787275,
#   'CCSD(T)': -47926.368933363745,
#   'CCSD(T) small': -47927.13581544759},
#  '12_2': {'LDA': -47634.9698963141,
#   'PBE': -47932.98830507024,
#   'B3LYP': -47963.56729137465,
#   'HF': -47731.634121294606,
#   'CCSD(T)': -47926.25211351475,
#   'CCSD(T) small': -47927.01317500627},
#  '16_2': {'LDA': -47634.9397254051,
#   'PBE': -47932.97135590046,
#   'B3LYP': -47963.648600013126,
#   'HF': -47732.00739954895,
#   'CCSD(T)': -47926.37034229623,
#   'CCSD(T) small': -47927.13692744567},
#  '18_1': {'LDA': -47634.949963116545,
#   'PBE': -47932.977436906534,
#   'B3LYP': -47963.56349090272,
#   'HF': -47731.65914649075,
#   'CCSD(T)': -47926.26655505704,
#   'CCSD(T) small': -47927.03175361309},
#  '54_2': {'LDA': -47634.880712763974,
#   'PBE': -47932.9374163967,
#   'B3LYP': -47963.577545589425,
#   'HF': -47731.86440560857,
#   'CCSD(T)': -47926.323592067725,
#   'CCSD(T) small': -47927.10203244308},
#  '59_2': {'LDA': -47634.92547318046,
#   'PBE': -47932.96360586191,
#   'B3LYP': -47963.64147321055,
#   'HF': -47732.010423862404,
#   'CCSD(T)': -47926.36901148787,
#   'CCSD(T) small': -47927.13782948122}}

# %%
df = pd.DataFrame(results_mol['AcNH2']['21_1']['DMCdla5']['Jopt']).transpose()
newindex = [float(tau) for tau in df.index]
df.index = newindex
df.sort_index(ascending=False, inplace=True)
df
#df[['ene','err']]
df[ df.index < 0.05 ]
#df[ df.index < 0.05 ]['ene']
# Out:
#                 ene       err     units TotTimeSim[au]           Pop  \
# 0.040 -25290.159667  0.030095  kcal/mol         1220.0  63974.552628
# 0.030 -25289.971374  0.031483  kcal/mol         1215.0  63964.995992
# 0.020  -25289.92147  0.035623  kcal/mol         1010.0    63977.9592
# 0.010 -25289.974516  0.030749  kcal/mol         1005.0  63979.291548
# 0.003 -25290.211134  0.029811  kcal/mol         1201.5  63992.274424
#
#         Pop-err   Var[au] tau_eff[au] corr-time[au]  \
# 0.040  0.829389  0.591824    0.038443      0.276016
# 0.030   0.72106  0.616691    0.029181      0.307369
# 0.020  0.639359  0.599023    0.019673        0.2961
# 0.010  0.451912  0.606618    0.009934      0.256561
# 0.003  0.226432  0.618657    0.002996      0.284465
#
#                                               machine N_MPI      cost  \
# 0.040  linuxpc-intel-slurm-parallel.peta4-icelake-zen   152  0.379274
# 0.030          linuxpc-intel-slurm-parallel.peta4-knl   320  2.068576
# 0.020  linuxpc-intel-slurm-parallel.peta4-icelake-zen   152  0.378092
# 0.010          linuxpc-intel-slurm-parallel.peta4-knl   320  2.066127
# 0.003      linuxpc-intel-slurm-parallel.peta4-icelake   152  0.351324
#
#       target_weight
# 0.040       64000.0
# 0.030       64000.0
# 0.020       64000.0
# 0.010       64000.0
# 0.003       64000.0

# %%
# Put into data the molecular informations of DMCdla5,Jopt in the format
# data[mol][method][mol_id]
# where method if the DFT functional or the DMC timestep, and err_{timestep} the error

data = {}
dmc_Jas = 'Jopt'
#dmc_Jas = 'Jdimer'

for mol in results_mol_dft:
    #print(mol)
    data[mol] = {}
    for mol_id in results_mol_dft[mol]:
        #print(mol_id)
        for func in results_mol_dft[mol][mol_id]:
            ene = results_mol_dft[mol][mol_id][func]
            #print(mol,mol_id,func,ene)
            if func not in data[mol]:
                data[mol][func] = {}
            data[mol][func][ mol_id ] = ene
        # add data DMC
        if mol_id in results_mol[mol]:
            try: 
                dmc = results_mol[mol][mol_id]['DMCdla5'][dmc_Jas]
                for tau in dmc:
                    #print(mol,mol_id,tau,dmc[tau]['ene'])
                    if 'ene' in dmc[tau]:
                        if tau not in data[mol]:
                            data[mol][tau] = {}
                            data[mol]['err_'+tau] = {}
                        data[mol][tau][ mol_id ] = dmc[tau]['ene']
                        data[mol]['err_'+tau][ mol_id ] = dmc[tau]['err']
            except:
                pass

#data

# %%
# tests

mol = mol_names[0]
print(mol)
df = pd.DataFrame( data[mol] )
#print(df)

for i in df:
    print(i)
    #print(df[i])

#df['LDA']
#df[:2]
#df.iloc[:,::2]
#df.mean()
df.index
# Out:
# AcNH2
# LDA
# PBE
# B3LYP
# HF
# CCSD(T)
# CCSD(T) small
# 0.10
# err_0.10
# 0.05
# err_0.05
# 0.02
# err_0.02
# 0.03
# err_0.03
# 0.04
# err_0.04
# 0.003
# err_0.003
# 0.01
# err_0.01
# 0.06
# err_0.06
# Index(['21_1', '21_2', '23_1', '53_2', '62_2'], dtype='object')

# %%
# Plot Effective timestep for representative molecules
verbose = False

for idx, mol in enumerate( mol_names ):
    print(f'MOLECULE: {mol}')
    
    df = pd.DataFrame( data[mol] )
    Xlabels = df.index
    X = np.arange(len(Xlabels))

    ref_mol_id = mol_info[mol]['ref']
    print( f'Doing {mol} ref={ref_mol_id}, idx={idx}' )

    fig, ax = plt.subplots(figsize=(10, 5) )
    ax.set_title(f'{mol}')

    ax.set_xlim([-0.5,-0.5+len(Xlabels)])
    ax.set_xticks(ticks=X)
    ax.set_xticklabels(labels=Xlabels,rotation=0)

    ax.set_ylabel(f'Energy - Energy({ref_mol_id}) [kcal/mol]')
    ax.set_xlabel('molecules')

    methods = list( df.columns )
    methods.sort()
    for method in methods[::-1]:
        if verbose: 
            print(method)
            print(df[method])

        if not method.startswith('err_'):

            try:
                Yref = float( df.at[ref_mol_id,method] )
                Y = np.array( df[method], dtype=np.double )
                c = dft_color( method )
                if method.startswith('0.'):
                    label = 'DMC '+method
                else:
                    label = method
                if (len( Y[ ~np.isnan(Y) ] )>1) or (method in ['0.003','0.01','0.03','0,10']) :
                    #print(f'{label} X={X} Y={Y}')
                    ax.plot( X, Y-Yref, 'o:', label=label , color=c )
                    err_method = 'err_'+method
                    if err_method in df:
                        Yerr = np.array( df[err_method], dtype=np.double )
                        ax.errorbar( X, Y-Yref, Yerr, color=c, fmt='.', capsize=3 )
            except:
                print( f'Exception with {method}: {Yref} {Y}' )
                pass

    ax.hlines(0,-1,len(X),color='black', lw=0.5)#, label='Target', linestyles='dashdot',
    #plt.ylim([0.86,1.02])
    #ax.set_yticklabels(['{:,.0f}'.format(x) for x in ax.get_yticks()])

    ax.legend( bbox_to_anchor=(1., 1.))

    fig.tight_layout()
    fig.savefig(f'FIG02b/DeltaE_{mol}.png',format='png',dpi=300)
# Out:
# MOLECULE: AcNH2
# Doing AcNH2 ref=21_1, idx=0
# MOLECULE: AcOH
# Doing AcOH ref=20_1, idx=1
# MOLECULE: Benzene
# Doing Benzene ref=24_1, idx=2
# MOLECULE: Cyclopentane
# Doing Cyclopentane ref=37_1, idx=3
# MOLECULE: Ethene
# Doing Ethene ref=30_2, idx=4
# MOLECULE: Ethyne
# Doing Ethyne ref=32_2, idx=5
# MOLECULE: MeNH2
# Doing MeNH2 ref=56_2, idx=6
# MOLECULE: MeOH
# Doing MeOH ref=55_2, idx=7
# MOLECULE: Neopentane
# Doing Neopentane ref=36_1, idx=8
# MOLECULE: Pentane
# Doing Pentane ref=34_1, idx=9
# MOLECULE: Peptide
# Doing Peptide ref=57_2, idx=10
# MOLECULE: Pyridine
# Doing Pyridine ref=25_1, idx=11
# MOLECULE: Uracil
# Doing Uracil ref=26_1, idx=12
# MOLECULE: Water
# Doing Water ref=01_2, idx=13

# %%
# Plot Effective timestep for representative molecules
verbose = False

for idx, mol in enumerate( mol_names ):
    print(f'MOLECULE: {mol}')

    if mol_info[mol]['test']:
        fig, ax = plt.subplots(figsize=(7, 7) )
        ax.set_title( f'{mol}' )

        df = pd.DataFrame( data[mol] )
        ax.set_ylabel(r'$\Delta E$ [kcal/mol]')
        ax.set_xlabel(r'$\Delta E$ DMC($\tau$=0.01) [kcal/mol]')
        
        ref_mol_id = mol_info[mol]['ref']
        Xref = df.at[ref_mol_id,'0.01']
        X    = np.array( df['0.01'], dtype=np.double )
        Xerr = np.array( df['err_0.01'], dtype=np.double )
        Xave = X.mean()

        ax.errorbar( X-Xref, X-Xref, xerr=None, yerr=Xerr, fmt='.:', color='green', label='DMC' )
        ax.plot( Xave-Xref, Xave-Xref, 'x', color='green')

        methods = list( df.columns )
        methods.sort()
        for method in methods[::-1]:
            if verbose: 
                print(method)
                print(df[method])

            if not method.startswith('err_') and not method.startswith('0.'):
                Yref = df.at[ref_mol_id,method]
                Y = np.array( df[method], dtype=np.double )
                #Yerr = np.array( df['err_0.01'], dtype=np.double )
                Yave = Y.mean()
                c = dft_color( method )
                ax.plot( X-Xref, Y-Yref, 'o', label=method , color=c )
                ax.plot( Xave-Xref, Yave-Yref, 'x', color=c)

        ax.legend() # bbox_to_anchor=(1., 1.))

        fig.tight_layout()
        fig.savefig(f'FIG02b/ScatterDeltaE_{mol}.png',format='png',dpi=300)
# Out:
# MOLECULE: AcNH2
# MOLECULE: AcOH
# MOLECULE: Benzene
# MOLECULE: Cyclopentane
# MOLECULE: Ethene
# MOLECULE: Ethyne
# MOLECULE: MeNH2
# MOLECULE: MeOH
# MOLECULE: Neopentane
# MOLECULE: Pentane
# MOLECULE: Peptide
# MOLECULE: Pyridine
# MOLECULE: Uracil
# MOLECULE: Water

# %%
# Plot Effective timestep for representative molecules
verbose = False

for idx, mol in enumerate( mol_names ):
    print(f'MOLECULE: {mol}')

    if mol_info[mol]['test']:
        fig, ax = plt.subplots(figsize=(7, 7) )
        ax.set_title( f'{mol}' )

        df = pd.DataFrame( data[mol] )
        ax.set_ylabel(r'$\Delta E$ [kcal/mol]')
        ax.set_xlabel(r'$\Delta E$ DMC($\tau$=0.01) [kcal/mol]')
        
        ref_mol_id = mol_info[mol]['ref']
        Xref = df.at[ref_mol_id,'0.01']
        X = np.array( df['0.01'], dtype=np.double )
        Xerr = np.array( df['err_0.01'], dtype=np.double )
        Xave = X.mean()

        ax.errorbar( X-Xref, X-Xref, xerr=None, yerr=Xerr, fmt='o:', color='green' )
        ax.plot( Xave-Xref, Xave-Xref, 'x', color='green')

        methods = list( df.columns )
        methods.sort()
        for method in methods[::-1]:
            if verbose: 
                print(method)
                print(df[method])

            #if not method.startswith('err_') and method.startswith('0.'):
            if method in ('0.10','0.03','0.01','0.003'):
                Yref = df.at[ref_mol_id,method]
                Y = np.array( df[method], dtype=np.double )
                Yerr = np.array( df['err_'+method], dtype=np.double )
                Yave = Y.mean()
                c = dft_color( method )
                ax.errorbar( X-Xref, Y-Yref, yerr=Yerr, fmt='o', label=method , color=c )
                ax.plot( Xave-Xref, Yave-Yref, 'x', color=c)

        ax.legend() # bbox_to_anchor=(1., 1.))

        fig.tight_layout()
        fig.savefig(f'FIG02b/ScatterDeltaDMCtau_{mol}.png',format='png',dpi=300)
# Out:
# MOLECULE: AcNH2
# MOLECULE: AcOH
# MOLECULE: Benzene
# MOLECULE: Cyclopentane
# MOLECULE: Ethene
# MOLECULE: Ethyne
# MOLECULE: MeNH2
# MOLECULE: MeOH
# MOLECULE: Neopentane
# MOLECULE: Pentane
# MOLECULE: Peptide
# MOLECULE: Pyridine
# MOLECULE: Uracil
# MOLECULE: Water

# %%
# Plot Effective timestep for representative molecules
verbose = False

ref_method = 'CCSD(T)'
print(f'ref_method = {ref_method}\n')

for idx, mol in enumerate( mol_names ):
    print(f'MOLECULE: {mol}')

    if mol_info[mol]['test']:
        fig, ax = plt.subplots(figsize=(7, 7) )
        ax.set_title( f'{mol}' )

        df = pd.DataFrame( data[mol] )
        ax.set_ylabel(r'$\Delta E$ [kcal/mol]')
        ax.set_xlabel(r'$\Delta E$ DMC($\tau$=0.01) [kcal/mol]')
        
        ref_mol_id = mol_info[mol]['ref']
        print(f'ref_mol_id = {ref_mol_id}\n')

        Xref = df.at[ref_mol_id,ref_method]
        X    = np.array( df[ref_method], dtype=np.double )
        Xave = X.mean()

        ax.plot( X-Xref, X-Xref, 'o:', color=dft_color(ref_method), label=ref_method )
        ax.plot( Xref-Xref, Xref-Xref, '*', markersize=10, color=dft_color(ref_method) )
        ax.plot( Xave-Xref, Xave-Xref, 'x', color=dft_color(ref_method))

        methods = list( df.columns )
        methods.sort()
        for method in methods[::-1]:
            if verbose: 
                print(method)
                print(df[method])

            #if not method.startswith('err_') and method.startswith('0.'):
            #if method in ('0.10'):
            if method in ('0.10','0.03','0.01','0.003'):
                Yref = df.at[ref_mol_id,method]
                Y = np.array( df[method], dtype=np.double )
                Yerr = np.array( df['err_'+method], dtype=np.double )
                Yave = Y.mean()
                c = dft_color( method )
                ax.errorbar( X-Xref, Y-Yref, yerr=Yerr, fmt='o', label=method , color=c )
                ax.plot( Xref-Xref, Yref-Yref, '*', markersize=10, color=c )
                ax.plot( Xave-Xref, Yave-Yref, 'x', color=c)

        ax.legend() # bbox_to_anchor=(1., 1.))

        fig.tight_layout()
        fig.savefig(f'FIG02b/ScatterCCSDT_DeltaDMCtau_{mol}.png',format='png',dpi=300)
    else:
        print('No test data!\n')
# Out:
# ref_method = CCSD(T)
#
# MOLECULE: AcNH2
# ref_mol_id = 21_1
#
# MOLECULE: AcOH
# ref_mol_id = 20_1
#
# MOLECULE: Benzene
# No test data!
#
# MOLECULE: Cyclopentane
# ref_mol_id = 37_1
#
# MOLECULE: Ethene
# No test data!
#
# MOLECULE: Ethyne
# No test data!
#
# MOLECULE: MeNH2
# No test data!
#
# MOLECULE: MeOH
# No test data!
#
# MOLECULE: Neopentane
# No test data!
#
# MOLECULE: Pentane
# No test data!
#
# MOLECULE: Peptide
# ref_mol_id = 57_2
#
# MOLECULE: Pyridine
# No test data!
#
# MOLECULE: Uracil
# ref_mol_id = 26_1
#
# MOLECULE: Water
# No test data!

# %%
# Plot Effective timestep for representative molecules
verbose = False

for idx, mol in enumerate( mol_names ):
    print(f'MOLECULE: {mol}')

    if mol_info[mol]['test']:
        fig, (ax1, ax2) = plt.subplots(1,2, sharey=True, figsize=(10, 5) )
        ax1.set_title( f'{mol}' )

        for ax in [ax1,ax2]:
            df = pd.DataFrame( data[mol] )
            ax.set_ylabel(r'$\Delta E$ [kcal/mol]')
            ax.set_xlabel(r'$\Delta E$ DMC($\tau$=0.01) [kcal/mol]')

            X = np.array( df['0.01'], dtype=np.double )
            Xerr = np.array( df['err_0.01'], dtype=np.double )
            Xave = X.mean()

            ref_mol_id = mol_info[mol]['ref']
            #Xref = df.at[ref_mol_id,'0.01']
            Xref = Xave
            
            ax.errorbar( X-Xref, X-Xref, xerr=None, yerr=Xerr, fmt='o:', color='green' )
            ax.plot( Xave-Xref, Xave-Xref, 'x', color='green')

        methods = list( df.columns )
        methods.sort()
        for method in methods[::-1]:
            if verbose: 
                print(method)
                print(df[method])

            if not method.startswith('err_') and not method.startswith('0.'):
                Y = np.array( df[method], dtype=np.double )
                Yave = Y.mean()
                #Yref = df.at[ref_mol_id,method]
                Yref = Yave
                c = dft_color( method )
                ax1.plot( X-Xref, Y-Yref, 'o', label=method , color=c )
                ax1.plot( Xave-Xref, Yave-Yref, 'x', color=c)

            if not method.startswith('err_') and method.startswith('0.'):
                Y = np.array( df[method], dtype=np.double )
                if np.all( ~np.isnan(Y) ):
                    Yerr = np.array( df['err_'+method], dtype=np.double )
                    Yave = Y.mean()
                    #Yref = df.at[ref_mol_id,method]
                    Yref = Yave
                    c = dft_color( method )
                    ax2.errorbar( X-Xref, Y-Yref, yerr=Yerr, fmt='o', label=method , color=c )
                    ax2.plot( Xave-Xref, Yave-Yref, 'x', color=c)

        ax1.legend() # bbox_to_anchor=(1., 1.))
        ax2.legend() # bbox_to_anchor=(1., 1.))

        fig.tight_layout()
        fig.savefig(f'FIG02b/ScatterDeltaAll_{mol}.png',format='png',dpi=300)
# Out:
# MOLECULE: AcNH2
# MOLECULE: AcOH
# MOLECULE: Benzene
# MOLECULE: Cyclopentane
# MOLECULE: Ethene
# MOLECULE: Ethyne
# MOLECULE: MeNH2
# MOLECULE: MeOH
# MOLECULE: Neopentane
# MOLECULE: Pentane
# MOLECULE: Peptide
# MOLECULE: Pyridine
# MOLECULE: Uracil
# MOLECULE: Water

# %%
# write the delta energy for each structure (mol_id) of each molecule 
# delta_mol_ref[mol][mol_id] = E[mol_id] - E[ref_mol_id]
# where E is the energy at the B3LYP level

delta_mol_ref = {}
refmethod = 'CCSD(T)'

for idx, mol in enumerate( mol_names ):

    ref_mol_id = mol_info[mol]['ref']
    print(f'MOLECULE: {mol}, ref {ref_mol_id}')

    ref_mol_id = mol_info[mol]['ref']
    s = pd.Series( data[mol][refmethod] )
    ds = s-s[ref_mol_id]
    
    delta_mol_ref[mol] = dict( ds )

# Save into file
import pickle
with open( dir_analysis+'delta_mol_ref.pkl', 'wb' ) as f:
    pickle.dump( delta_mol_ref, f, pickle.HIGHEST_PROTOCOL )

#delta_mol_ref[mol][mol_id]
delta_mol_ref
# Out:
# MOLECULE: AcNH2, ref 21_1
# MOLECULE: AcOH, ref 20_1
# MOLECULE: Benzene, ref 24_1
# MOLECULE: Cyclopentane, ref 37_1
# MOLECULE: Ethene, ref 30_2
# MOLECULE: Ethyne, ref 32_2
# MOLECULE: MeNH2, ref 56_2
# MOLECULE: MeOH, ref 55_2
# MOLECULE: Neopentane, ref 36_1
# MOLECULE: Pentane, ref 34_1
# MOLECULE: Peptide, ref 57_2
# MOLECULE: Pyridine, ref 25_1
# MOLECULE: Uracil, ref 26_1
# MOLECULE: Water, ref 01_2
# {'AcNH2': {'21_1': 0.0,
#   '21_2': -0.0016018896421883255,
#   '23_1': 0.056446028349455446,
#   '53_2': -0.6462552996526938,
#   '62_2': -0.7047833829710726},
#  'AcOH': {'20_1': 0.0,
#   '20_2': -0.0015795505605638027,
#   '22_1': 0.06958964341902174,
#   '52_2': -1.2759445201372728,
#   '60_2': -1.2525766221515369,
#   '61_2': -1.3299330584995914,
#   '63_2': -1.294662746367976},
#  'Benzene': {'24_1': 0.0,
#   '24_2': 0.00017475959612056613,
#   '27_1': -0.0024995954299811274,
#   '28_1': 0.010133545962162316,
#   '30_1': -0.005731047625886276,
#   '39_1': -0.005714042315958068,
#   '40_1': -0.004324625158915296,
#   '47_1': -0.003029898216482252,
#   '47_2': 0.004498067020904273,
#   '49_1': -0.001238377153640613,
#   '50_1': 0.0009104441269300878,
#   '52_1': 0.018470864568371326,
#   '53_1': 0.041799982864176854,
#   '54_1': 0.000253071979386732,
#   '55_1': 0.003973286249674857,
#   '56_1': -0.0005966298340354115,
#   '57_1': 0.0027571854589041322,
#   '63_1': 0.002205171069363132},
#  'Cyclopentane': {'37_1': 0.0,
#   '38_1': 0.006658622602117248,
#   '38_2': 0.007278030810994096,
#   '39_2': 0.010707209192332812,
#   '42_2': 0.023519941954873502},
#  'Ethene': {'30_2': 0.0,
#   '31_2': -0.00020381297508720309,
#   '33_2': -0.0001287008708459325,
#   '44_1': -0.003224863416107837,
#   '64_2': 0.017556906437675934},
#  'Ethyne': {'32_2': 0.0,
#   '45_1': -0.02666486148518743,
#   '50_2': -0.016992781238514,
#   '51_1': -0.030219854226743337,
#   '51_2': -0.026148050012125168,
#   '59_1': -0.010139758225705009,
#   '60_1': 0.024343288634554483,
#   '65_2': 0.028619407828955445},
#  'MeNH2': {'03_2': -0.025838691028184257,
#   '06_2': -0.02576313966710586,
#   '09_1': -0.0025221228061127476,
#   '10_1': 0.005449612559459638,
#   '10_2': -0.014885563410643954,
#   '11_1': 0.017842859553638846,
#   '12_1': -0.01825136400293559,
#   '14_2': -0.015802219793840777,
#   '56_2': 0.0,
#   '66_1': 0.0024514659744454548},
#  'MeOH': {'02_2': -0.015504908878938295,
#   '05_1': 0.05592319286370184,
#   '05_2': -0.022470254931249656,
#   '06_1': 0.22184063358872663,
#   '07_1': 0.14730501150188502,
#   '08_1': 0.037724476351286285,
#   '09_2': -0.0328203521494288,
#   '13_2': -0.033902543829753995,
#   '19_1': 0.20750507655611727,
#   '55_2': 0.0},
#  'Neopentane': {'35_2': 0.0004156579962000251,
#   '36_1': 0.0,
#   '36_2': 9.399995906278491e-05,
#   '37_2': 0.0004892641009064391,
#   '40_2': 0.006494718792964704,
#   '43_2': 0.01244884375773836},
#  'Pentane': {'34_1': 0.0,
#   '34_2': -0.000281246830127202,
#   '35_1': -0.002093852002872154,
#   '41_2': 0.05086721295083407,
#   '44_2': 0.0027174017450306565,
#   '45_2': 0.03502050318638794,
#   '46_2': 0.02898599508625921,
#   '61_1': 0.033418362523661926,
#   '62_1': 0.031438339559827},
#  'Peptide': {'04_2': 0.06704907203675248,
#   '07_2': -0.0058943867043126374,
#   '11_2': -0.10212328948546201,
#   '13_1': -0.04750662064179778,
#   '14_1': 0.0756839525711257,
#   '15_1': 0.1601772942522075,
#   '15_2': 0.07840511933318339,
#   '16_1': 0.04973275025258772,
#   '46_1': -0.013388906023465097,
#   '57_2': 0.0,
#   '64_1': -0.026639824121957645},
#  'Pyridine': {'18_2': 0.004080840270034969,
#   '19_2': 0.008064919558819383,
#   '25_1': 0.0,
#   '25_2': -0.003356199769768864,
#   '27_2': -0.004891699645668268,
#   '29_1': 0.013910925772506744,
#   '33_1': -0.015989843173883855,
#   '48_1': -0.0034881009196396917,
#   '48_2': 0.0017942193371709436,
#   '49_2': 0.0035296416317578405,
#   '58_1': 0.017635909083765,
#   '58_2': 0.017643250845139846,
#   '65_1': -0.00623599931714125,
#   '66_2': -0.0011647710634861141},
#  'Uracil': {'17_1': 0.34810007296619006,
#   '17_2': 0.22967576151131652,
#   '22_2': 0.38981835488812067,
#   '23_2': 0.500410236621974,
#   '26_1': 0.0,
#   '26_2': 0.0,
#   '28_2': -0.3052883670607116,
#   '29_2': -0.23944912079605274,
#   '31_1': -0.3178654724324588,
#   '32_1': -0.24571636973996647,
#   '41_1': -0.3375097675889265,
#   '42_1': -0.34930268247262575,
#   '43_1': -0.3113625960831996},
#  'Water': {'01_1': 0.030970661566243507,
#   '01_2': 0.0,
#   '02_1': 0.0417951510680723,
#   '03_1': 0.10874608164886013,
#   '04_1': 0.08717102249647724,
#   '08_2': -0.0012708190770354122,
#   '12_2': 0.11554902992065763,
#   '16_2': -0.0026797515602083877,
#   '18_1': 0.1011074876296334,
#   '54_2': 0.04407047694257926,
#   '59_2': -0.0013489432021742687}}

# %%
df_delta = pd.DataFrame(delta_mol_ref).T
df_delta
# Out:
#               21_1      21_2      23_1      53_2      62_2  20_1     20_2  \
# AcNH2          0.0 -0.001602  0.056446 -0.646255 -0.704783   NaN      NaN
# AcOH           NaN       NaN       NaN       NaN       NaN   0.0 -0.00158
# Benzene        NaN       NaN       NaN       NaN       NaN   NaN      NaN
# Cyclopentane   NaN       NaN       NaN       NaN       NaN   NaN      NaN
# Ethene         NaN       NaN       NaN       NaN       NaN   NaN      NaN
# Ethyne         NaN       NaN       NaN       NaN       NaN   NaN      NaN
# MeNH2          NaN       NaN       NaN       NaN       NaN   NaN      NaN
# MeOH           NaN       NaN       NaN       NaN       NaN   NaN      NaN
# Neopentane     NaN       NaN       NaN       NaN       NaN   NaN      NaN
# Pentane        NaN       NaN       NaN       NaN       NaN   NaN      NaN
# Peptide        NaN       NaN       NaN       NaN       NaN   NaN      NaN
# Pyridine       NaN       NaN       NaN       NaN       NaN   NaN      NaN
# Uracil         NaN       NaN       NaN       NaN       NaN   NaN      NaN
# Water          NaN       NaN       NaN       NaN       NaN   NaN      NaN
#
#                  22_1      52_2      60_2  ...  01_2      02_1      03_1  \
# AcNH2             NaN       NaN       NaN  ...   NaN       NaN       NaN
# AcOH          0.06959 -1.275945 -1.252577  ...   NaN       NaN       NaN
# Benzene           NaN       NaN       NaN  ...   NaN       NaN       NaN
# Cyclopentane      NaN       NaN       NaN  ...   NaN       NaN       NaN
# Ethene            NaN       NaN       NaN  ...   NaN       NaN       NaN
# Ethyne            NaN       NaN       NaN  ...   NaN       NaN       NaN
# MeNH2             NaN       NaN       NaN  ...   NaN       NaN       NaN
# MeOH              NaN       NaN       NaN  ...   NaN       NaN       NaN
# Neopentane        NaN       NaN       NaN  ...   NaN       NaN       NaN
# Pentane           NaN       NaN       NaN  ...   NaN       NaN       NaN
# Peptide           NaN       NaN       NaN  ...   NaN       NaN       NaN
# Pyridine          NaN       NaN       NaN  ...   NaN       NaN       NaN
# Uracil            NaN       NaN       NaN  ...   NaN       NaN       NaN
# Water             NaN       NaN       NaN  ...   0.0  0.041795  0.108746
#
#                   04_1      08_2      12_2     16_2      18_1     54_2  \
# AcNH2              NaN       NaN       NaN      NaN       NaN      NaN
# AcOH               NaN       NaN       NaN      NaN       NaN      NaN
# Benzene            NaN       NaN       NaN      NaN       NaN      NaN
# Cyclopentane       NaN       NaN       NaN      NaN       NaN      NaN
# Ethene             NaN       NaN       NaN      NaN       NaN      NaN
# Ethyne             NaN       NaN       NaN      NaN       NaN      NaN
# MeNH2              NaN       NaN       NaN      NaN       NaN      NaN
# MeOH               NaN       NaN       NaN      NaN       NaN      NaN
# Neopentane         NaN       NaN       NaN      NaN       NaN      NaN
# Pentane            NaN       NaN       NaN      NaN       NaN      NaN
# Peptide            NaN       NaN       NaN      NaN       NaN      NaN
# Pyridine           NaN       NaN       NaN      NaN       NaN      NaN
# Uracil             NaN       NaN       NaN      NaN       NaN      NaN
# Water         0.087171 -0.001271  0.115549 -0.00268  0.101107  0.04407
#
#                   59_2
# AcNH2              NaN
# AcOH               NaN
# Benzene            NaN
# Cyclopentane       NaN
# Ethene             NaN
# Ethyne             NaN
# MeNH2              NaN
# MeOH               NaN
# Neopentane         NaN
# Pentane            NaN
# Peptide            NaN
# Pyridine           NaN
# Uracil             NaN
# Water        -0.001349
#
# [14 rows x 132 columns]
